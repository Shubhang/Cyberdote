# %%
import pandas as pd

# %%
# !ls
# Out:
# Combining-Toxic-Vars.ipynb        balanced-dataset.ipynb
# Data-Cleaning-Preprocessing.ipynb initiate.sh
# README.md                         train-toxic-var.csv

# %%
df = pd.read_csv("train-toxic-var.csv")

# %%
df.rename(columns={'Toxic-or-not':'toxicity'}, inplace = True)

# %%
df
# Out:
#         Unnamed: 0                id  \
# 0                0  0000997932d777bf
# 1                1  000103f0d9cfb60f
# 2                2  000113f07ec002fd
# 3                3  0001b41b1c6bb37e
# 4                4  0001d958c54c6e35
# ...            ...               ...
# 159249      159249  ffe987279560d7ff
# 159250      159250  ffea4adeee384e90
# 159251      159251  ffee36eab5c267c9
# 159252      159252  fff125370e4aaaf3
# 159253      159253  fff46fc426af1f9a
#
#                                              comment_text  toxicity
# 0       Explanation\nWhy the edits made under my usern...         0
# 1       D'aww! He matches this background colour I'm s...         0
# 2       Hey man, I'm really not trying to edit war. It...         0
# 3       "\nMore\nI can't make any real suggestions on ...         0
# 4       You, sir, are my hero. Any chance you remember...         0
# ...                                                   ...       ...
# ...

# %%
df_zeros = df[df.toxicity == 0]
df_ones = df[df.toxicity == 1]

# %%
df_zeros
# Out:
#         Unnamed: 0                id  \
# 0                0  0000997932d777bf
# 1                1  000103f0d9cfb60f
# 2                2  000113f07ec002fd
# 3                3  0001b41b1c6bb37e
# 4                4  0001d958c54c6e35
# ...            ...               ...
# 159249      159249  ffe987279560d7ff
# 159250      159250  ffea4adeee384e90
# 159251      159251  ffee36eab5c267c9
# 159252      159252  fff125370e4aaaf3
# 159253      159253  fff46fc426af1f9a
#
#                                              comment_text  toxicity
# 0       Explanation\nWhy the edits made under my usern...         0
# 1       D'aww! He matches this background colour I'm s...         0
# 2       Hey man, I'm really not trying to edit war. It...         0
# 3       "\nMore\nI can't make any real suggestions on ...         0
# 4       You, sir, are my hero. Any chance you remember...         0
# ...                                                   ...       ...
# ...

# %%
df_ones
# Out:
#         Unnamed: 0                id  \
# 6                6  0002bcb3da6cb337
# 12              12  0005c987bdfc9d4b
# 16              16  0007e25b2121310b
# 42              42  001810bf8c45bf5f
# 43              43  00190820581d90ce
# ...            ...               ...
# 159177      159177  fef4cf7ba0012866
# 159197      159197  ff39a2895fc3b40e
# 159224      159224  ffa33d3122b599d6
# 159229      159229  ffb47123b2d82762
# 159237      159237  ffbdbb0483ed0841
#
#                                              comment_text  toxicity
# 6            COCKSUCKER BEFORE YOU PISS AROUND ON MY WORK         1
# 12      Hey... what is it..\n@ | talk .\nWhat is it......         1
# 16      Bye! \n\nDon't look, come or think of comming ...         1
# 42      You are gay or antisemmitian? \n\nArchangel WH...         1
# 43               FUCK YOUR FILTHY MOTHER IN THE ASS, DRY!         1
# ...                                                   ...       ...
# ...

# %%
df_zeros_selected = df_zeros.sample(n=15908)

# %%
df_new = pd.concat([df_zeros_selected, df_ones], ignore_index = True)

# %%
df_new
# Out:
#        Unnamed: 0                id  \
# 0           66851  b327c3f3db0e52f0
# 1           38102  65df0d79ab6ebfbc
# 2           54785  92abe405584348e3
# 3           39379  694545f8286d07b4
# 4          144612  146fcd3acb84e847
# ...           ...               ...
# 31811      159177  fef4cf7ba0012866
# 31812      159197  ff39a2895fc3b40e
# 31813      159224  ffa33d3122b599d6
# 31814      159229  ffb47123b2d82762
# 31815      159237  ffbdbb0483ed0841
#
#                                             comment_text  toxicity
# 0      Galaune & co\nI already referenced and expande...         0
# 1      "\n\nhow do I post a new title without = signs...         0
# 2      "==Image source problem with Image:Visuel2.jpg...         0
# 3      "\nThere, that's what I am trying to say.\nHin...         0
# 4      it is true and where does it say i have to ins...         0
# ...                                                  ...       ...
# ...

# %%
df_new.to_csv("train_balanced.csv")
